# %%
name = "Shrut"

# %%
name #In jupyter notebook no need to define print statement
# Out:
# 'Shrut'

# %%
name.upper()
# Out:
# 'SHRUT'

# %%
name.endswith("ut")
# Out:
# True

# %%
name.endswith("ry")
# Out:
# False

# %%
SerName="JIVANEE"

# %%
SerName.lower()
# Out:
# 'jivanee'

# %%
SerName.count("E")
# Out:
# 2

# %%
str = " code with harry "
print(len(str))
# Out:
# 17

# %%
str.strip() #removes leading and trailing spaces.
# Out:
# 'code with harry'

# %%
str.replace("harry","shaili")
# Out:
# ' code with shaili '

# %%
str1="apple,banana,stobary" # A string into a list
str1.split(",")
# Out:
# ['apple', 'banana', 'stobary']

# %%
str.find("harry") #returns the index of the first occurrences of a substring.
# Out:
# 11

# %%
ste="I like rose"
ste.startswith("I like")
# Out:
# True

# %%
statement="I like rose"," and lottus."
print("".join(statement))
# Out:
# I like rose and lottus.

# %%
s = "see you soon" # 0 to n-1 character print (string slicing)
s[0:7]
# Out:
# 'see you'

# %%
print(s[1:-1])
len(s)
# Out:
# ee you soo
# 12

# %%
s[1:11] #Convert Negetive index to positive indexes [Strating index:ending index -->len(str)-1]
# Out:
# 'ee you soo'

# %%
s[-12:-1]
# Out:
# 'see you soo'

# %%
s[0:11]
# Out:
# 'see you soo'
