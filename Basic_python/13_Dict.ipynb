# %% [markdown]
# #### Dict is a Data-structure to store key-value pairs

# %% [markdown]
# ##### A dict in python is an unordered. mutable and key-value pair collection.
# ##### IT aollow efficient data retrieval and modification.

# %%
d = {}

# %%
type(d)
# Out:
# dict

# %%
# Dictionary with key-value pairs
student={
    "Name":"Jay",
    "Age":21,
    "Grade":"A"
}

# %%
student["Name"]
# Out:
# 'Jay'

# %%
r = student.get("name4") # Use get method return none but withou use get method and acsess key return error

# %%
print(r)
# Out:
# None

# %%
student={
    "Name":"Jay",
    "Age":21,
    "Grade":"A"
}

# %%
print(student["Age"])
# Out:
# 21

# %%
student["Age"]=23 # Modify value

# %%
student
# Out:
# {'Name': 'Jay', 'Age': 23, 'Grade': 'A'}

# %%
student.keys()
# Out:
# dict_keys(['Name', 'Age', 'Grade'])

# %%
student.values()
# Out:
# dict_values(['Jay', 23, 'A'])

# %%
student.items() # gives key-value pairs
# Out:
# dict_items([('Name', 'Jay'), ('Age', 23), ('Grade', 'A')])

# %%
student.update({"Name":"Shaili","languages":"python"})

# %%
student
# Out:
# {'Name': 'Shaili', 'Age': 23, 'Grade': 'A', 'languages': 'python'}

# %%
student.pop("Grade")
# Out:
# 'A'

# %%
student
# Out:
# {'Name': 'Shaili', 'Age': 23, 'languages': 'python'}

# %%
student.popitem()
# Out:
# ('languages', 'python')

# %%
student
# Out:
# {'Name': 'Shaili', 'Age': 23}

# %%
student.setdefault("Profession")

# %%
student
# Out:
# {'Name': 'Shaili', 'Age': 23, 'Profession': None}

# %%
new_dict=student.copy() # Return a shallow copy of the dict

# %%
new_dict
# Out:
# {'Name': 'Shaili', 'Age': 23, 'Profession': None}

# %%
student.clear()

# %%
student
# Out:
# {}
