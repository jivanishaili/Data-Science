# %%
f = open("text.txt","r")

# %%
f.read()
# Out:
# 'My name is Shaili.\nI like python languages.\nI study this language daily.'

# %%
f.close()

# %%
s = "This is a nice way to learn Data science."

# %%
f = open("shaili.txt","w")

# %%
f.write(s)
# Out:
# 41

# %%
f.close()

# %%
with open("text.txt","r") as file:
    content = file.read()
    print(content) # No need to manually close the file
# Out:
# My name is Shaili.
# I like python languages.
# I study this language daily.

# %%
file = open("text.txt","a")
file.write("\n THIS IS AN ADDITIONAL LINE.")
file.close()
