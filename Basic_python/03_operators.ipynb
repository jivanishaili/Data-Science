# %% [markdown]
# a = 11
# b = 5

# %% [markdown]
# ## Arithmetic operator

# %%
a + b
# Out:
# 16

# %%
a - b
# Out:
# 6

# %%
a * b
# Out:
# 55

# %%
a / b #divison --> return a float
# Out:
# 2.2

# %%
a // b #Floor division --> return an integer
# Out:
# 2

# %%
a ** b #exponetiation
# Out:
# 161051

# %%
2 ** 5
# Out:
# 32

# %%
a % b
# Out:
# 1

# %% [markdown]
# ## Comparision operator

# %%
a = 45
b = 20

# %%
a > b
# Out:
# True

# %%
a < b
# Out:
# False

# %%
a >= b # if a is grater than true or a is equal to b also true given
# Out:
# True

# %%
c = 45

# %%
a == c #check quality [is a equal to c ?]
# Out:
# True

# %%
b != c # is b not equal to c ?
# Out:
# True

# %%
a = 5
b = 5

# %%
a >= b # a grater or equal to b ? --> give true because a equal to b.
# Out:
# True

# %%
a <= b
# Out:
# True

# %% [markdown]
# ## Logical operator

# %%
b1 = True
b2 = False

# %%
not(b1)
# Out:
# False

# %%
not(b2)
# Out:
# True

# %%
b1 or b2
# Out:
# True

# %%
b1 and b2
# Out:
# False

# %% [markdown]
# ## Bitwise operator

# %% [markdown]
# ####
# Binary me convert karke bits par operate karte hai

# %% [markdown]
# ## Assignment operator

# %%
a = 45

# %%
a -= 4

# %%
a
# Out:
# 41

# %%
a += 4

# %%
a
# Out:
# 45

# %%
a = 11

# %%
a //= 2

# %%
a
# Out:
# 5

# %%
a = 11
a **= 2

# %%
a
# Out:
# 121
