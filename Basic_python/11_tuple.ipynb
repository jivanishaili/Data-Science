# %%
e = ()

# %%
e
# Out:
# ()

# %%
type(e)
# Out:
# tuple

# %%
My_tuple = (2,3,65,78,4)

# %%
My_tuple
# Out:
# (2, 3, 65, 78, 4)

# %%
len(My_tuple)
# Out:
# 5

# %% [markdown]
# ### indexing

# %%
My_tuple[3]
# Out:
# 78

# %% [markdown]
# ### slicing

# %%
My_tuple[0:3]
# Out:
# (2, 3, 65)

# %% [markdown]
# ### Tuple paking and unpaking

# %%
# Paking
person=("Alice",25,"Engineer")

# %%
# UnPaking
name,age,profession=person

# %%
name
# Out:
# 'Alice'

# %%
age
# Out:
# 25

# %%
profession
# Out:
# 'Engineer'

# %% [markdown]
# ### common tuple method

# %%
My_tuple = (2,3,45,78,2,45)

# %%
My_tuple.count(45)
# Out:
# 2

# %%
My_tuple.index(78)
# Out:
# 3
