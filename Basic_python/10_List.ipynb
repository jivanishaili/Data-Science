# %% [markdown]
# #### List -> List is an ordered , mutable collection of element in python.

# %% [markdown]
# --> Strings methods return us a new string. BUT
# ### List mutable means that, the methods of the list , in most of the case will modify original list. Those methods change the original list. [list methods return modify list.]

# %%
l = [3,4,5,6]

# %%
l
# Out:
# [3, 4, 5, 6]

# %%
l.append(7)

# %%
l
# Out:
# [3, 4, 5, 6, 7]

# %%
l2=[8,9]

# %%
l.extend(l2)

# %%
l
# Out:
# [3, 4, 5, 6, 7, 8, 9]

# %%
l[4]
# Out:
# 7

# %%
l[0]=1

# %%
l
# Out:
# [1, 4, 5, 6, 7, 8, 9]

# %%
l.insert(1,2) #insert 2 at index 1

# %%
l
# Out:
# [1, 2, 4, 5, 6, 7, 8, 9]

# %%
number=l.pop(4)

# %%
number # pop 6 that index 4
# Out:
# 6

# %%
l
# Out:
# [1, 2, 4, 5, 7, 8, 9]

# %%
l.index(2) #return index(position) 1 for element 2
# Out:
# 1

# %%
l.append(4)

# %%
l
# Out:
# [1, 2, 3, 4, 5, 7, 8, 9, 2, 4]

# %%
l.count(4)
# Out:
# 2

# %%
l.sort() #change and sorts the original list in accending order

# %%
l
# Out:
# [1, 2, 2, 3, 4, 4, 5, 7, 8, 9]

# %%
l.reverse()

# %%
l
# Out:
# [9, 8, 7, 5, 4, 4, 3, 2, 2, 1]

# %%
newl=[1,54,21,32,18]

# %%
sorted(newl) # obtain a new list which is sorted version of the original list But not change original list it's as it is.
# Out:
# [1, 18, 21, 32, 54]

# %%
newl
# Out:
# [1, 54, 21, 32, 18]

# %% [markdown]
# ### Nested list

# %%
y = [2,4,7,True,False,[4,7]]

# %%
y
# Out:
# [2, 4, 7, True, False, [4, 7]]

# %%
y[5][0] # Acsess nested list
# Out:
# 4

# %%
y[5][1]
# Out:
# 7

# %% [markdown]
# ### List concatenation

# %%
list1=[1,2,3,4]

# %%
list2=[5,6,7,8]

# %%
list1+list2 # obtain new list not change original list.
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
list2
# Out:
# [5, 6, 7, 8]

# %% [markdown]
# ### check membership of particular element

# %%
list2
# Out:
# [5, 6, 7, 8]

# %%
if 33 in list2:
    print("Yes")
else:
    print("No")
# Out:
# No

# %%
8 in list2 # Return Boolean value
# Out:
# True

# %% [markdown]
# ### split a particular string
# --> splitting a string to a list

# %%
s = "ram-shyam-jay-madhav-bhavy-shrut-granth"

# %%
s.split("-")
# Out:
# ['ram', 'shyam', 'jay', 'madhav', 'bhavy', 'shrut', 'granth']
