# %%
a = {} # Create empty dict

# %%
type(a)
# Out:
# dict

# %%
b = set() # Create empty set

# %%
type(b)
# Out:
# set

# %% [markdown]
# #### In set unique collection of element.

# %%
s = {7,5,5,1,9,2} # oorder not important

# %%
s
# Out:
# {1, 2, 5, 7, 9}

# %% [markdown]
# ### Store diff type of value

# %%
set = {"Ram",True,"sita",45,8.9}

# %%
set
# Out:
# {45, 8.9, 'Ram', True, 'sita'}

# %% [markdown]
# #### creating a set from a list

# %%
# unique_numbers = set([1,2,2,3,4,4,5])
# print(unique_numbers) #{1,2,3,4,5}

# %%
s = {7,5,5,1,9,2}

# %%
s.add(3)

# %%
s
# Out:
# {1, 2, 3, 5, 7, 9}

# %%
s.update([7,64,233])

# %%
s
# Out:
# {1, 2, 3, 5, 7, 9, 64, 233}

# %%
s1={3,4,5,6}

s1.remove(4)

# %%
s1
# Out:
# {3, 5, 6}

# %%
s1.discard(5)

# %%
s1
# Out:
# {3, 6}

# %%
s1.pop()
# Out:
# 3

# %%
s1
# Out:
# {6}

# %%
s1.clear()

# %%
s1
# Out:
# set()

# %%
set1={1,2,3,4}
set2={3,4,5,6}

# %%
set1.union(set2) # return new set
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
set1
# Out:
# {1, 2, 3, 4}

# %%
set2
# Out:
# {3, 4, 5, 6}

# %%
set1.intersection(set2)
# Out:
# {3, 4}

# %%
sub = {1,3}

# %%
sub.issubset(set1) # sub is subset of set1
# Out:
# True

# %%
set1.issuperset(sub) # sub ni all value include che set1 ma so true
# Out:
# True
