# %%
code = 2000
match code:
    case 200:
        print("Response ok")
    case 400:
        print("Bad response")
    case 404:
        print("Not fund")
    case _:
        print("Nothing mathched / Unkown status")
print("End of program")
# Out:
# Nothing mathched / Unkown status
# End of program

# %% [markdown]
# ### match case using with function

# %%
def http_status(code):
    match code:
        case 200:
            return "OK"
        case 400:
            return "Bad Request"
        case 404:
            return "Not Found"
        case 500:
            return "Internal Server Error"
        case _:
            return "Unknown Status"

print(http_status(200))  # Output: OK
print(http_status(404))  # Output: Not Found
# Out:
# OK
# Not Found
