# %%
import pandas as pd

# %%
df = pd.read_csv("data_cleaning_sample.csv")

# %%
df
# Out:
#       Name   Age      City Gender               Email    JoinDate
# 0     Jenu  20.0  New York      F    Jenu54@gmail.com    1/5/2021
# 1  Krishna  21.0     Surat      M  Krishna4@gmail.com  15/06/2020
# 2   Khushi   NaN     Delhi      F   Khushi1@gmail.com  20/07/2021
# 3     Metu  19.0    Mumbai      F      Metu@gmail.com  12/11/2019
# 4      NaN  22.0  Banglore      M      Shrut@gmal.com         NaN
# 5     Jenu  20.0  New York      F    Jenu54@gmail.com    1/5/2021
# 6     Metu  19.0    Mumbai      F      Metu@gmail.com  12/11/2019
# 7     Metu  19.0    Mumbai      F      Metu@gmail.com  12/11/2019

# %%
df.isnull()
# Out:
#     Name    Age   City  Gender  Email  JoinDate
# 0  False  False  False   False  False     False
# 1  False  False  False   False  False     False
# 2  False   True  False   False  False     False
# 3  False  False  False   False  False     False
# 4   True  False  False   False  False      True
# 5  False  False  False   False  False     False
# 6  False  False  False   False  False     False
# 7  False  False  False   False  False     False

# %%
df.isnull().sum()
# Out:
# Name        1
# Age         1
# City        0
# Gender      0
# Email       0
# JoinDate    1
# dtype: int64

# %%
df.dropna()
# Out:
#       Name   Age      City Gender               Email    JoinDate
# 0     Jenu  20.0  New York      F    Jenu54@gmail.com    1/5/2021
# 1  Krishna  21.0     Surat      M  Krishna4@gmail.com  15/06/2020
# 3     Metu  19.0    Mumbai      F      Metu@gmail.com  12/11/2019
# 5     Jenu  20.0  New York      F    Jenu54@gmail.com    1/5/2021
# 6     Metu  19.0    Mumbai      F      Metu@gmail.com  12/11/2019
# 7     Metu  19.0    Mumbai      F      Metu@gmail.com  12/11/2019

# %%
df.dropna(axis=1)
# Out:
#        City Gender               Email
# 0  New York      F    Jenu54@gmail.com
# 1     Surat      M  Krishna4@gmail.com
# 2     Delhi      F   Khushi1@gmail.com
# 3    Mumbai      F      Metu@gmail.com
# 4  Banglore      M      Shrut@gmal.com
# 5  New York      F    Jenu54@gmail.com
# 6    Mumbai      F      Metu@gmail.com
# 7    Mumbai      F      Metu@gmail.com

# %%
df.fillna(0)
# Out:
#       Name   Age      City Gender               Email    JoinDate
# 0     Jenu  20.0  New York      F    Jenu54@gmail.com    1/5/2021
# 1  Krishna  21.0     Surat      M  Krishna4@gmail.com  15/06/2020
# 2   Khushi   0.0     Delhi      F   Khushi1@gmail.com  20/07/2021
# 3     Metu  19.0    Mumbai      F      Metu@gmail.com  12/11/2019
# 4        0  22.0  Banglore      M      Shrut@gmal.com           0
# 5     Jenu  20.0  New York      F    Jenu54@gmail.com    1/5/2021
# 6     Metu  19.0    Mumbai      F      Metu@gmail.com  12/11/2019
# 7     Metu  19.0    Mumbai      F      Metu@gmail.com  12/11/2019

# %% [markdown]
# #### replace Missing value with the average

# %%
df["Age"].fillna(df["Age"].mean())
# Out:
# 0    20.0
# 1    21.0
# 2    20.0
# 3    19.0
# 4    22.0
# 5    20.0
# 6    19.0
# 7    19.0
# Name: Age, dtype: float64

# %%
df.ffill()
# Out:
#       Name   Age      City Gender               Email    JoinDate
# 0     Jenu  20.0  New York      F    Jenu54@gmail.com    1/5/2021
# 1  Krishna  21.0     Surat      M  Krishna4@gmail.com  15/06/2020
# 2   Khushi  21.0     Delhi      F   Khushi1@gmail.com  20/07/2021
# 3     Metu  19.0    Mumbai      F      Metu@gmail.com  12/11/2019
# 4     Metu  22.0  Banglore      M      Shrut@gmal.com  12/11/2019
# 5     Jenu  20.0  New York      F    Jenu54@gmail.com    1/5/2021
# 6     Metu  19.0    Mumbai      F      Metu@gmail.com  12/11/2019
# 7     Metu  19.0    Mumbai      F      Metu@gmail.com  12/11/2019

# %%
df.bfill()
# Out:
#       Name   Age      City Gender               Email    JoinDate
# 0     Jenu  20.0  New York      F    Jenu54@gmail.com    1/5/2021
# 1  Krishna  21.0     Surat      M  Krishna4@gmail.com  15/06/2020
# 2   Khushi  19.0     Delhi      F   Khushi1@gmail.com  20/07/2021
# 3     Metu  19.0    Mumbai      F      Metu@gmail.com  12/11/2019
# 4     Jenu  22.0  Banglore      M      Shrut@gmal.com    1/5/2021
# 5     Jenu  20.0  New York      F    Jenu54@gmail.com    1/5/2021
# 6     Metu  19.0    Mumbai      F      Metu@gmail.com  12/11/2019
# 7     Metu  19.0    Mumbai      F      Metu@gmail.com  12/11/2019

# %%
df1 = pd.read_csv("data_cleaning_sample.csv")

# %%
df1
# Out:
#       Name   Age      City Gender               Email    JoinDate
# 0     Jenu  20.0  New York      F    Jenu54@gmail.com    1/5/2021
# 1  Krishna  21.0     Surat      M  Krishna4@gmail.com  15/06/2020
# 2   Khushi   NaN     Delhi      F   Khushi1@gmail.com  20/07/2021
# 3     Metu  19.0    Mumbai      F      Metu@gmail.com  12/11/2019
# 4      NaN  22.0  Banglore      M      Shrut@gmal.com         NaN
# 5     Jenu  20.0  New York      F    Jenu54@gmail.com    1/5/2021
# 6     Metu  19.0    Mumbai      F      Metu@gmail.com  12/11/2019
# 7     Metu  19.0    Mumbai      F      Metu@gmail.com  12/11/2019

# %%
df1.duplicated() # Check row wise
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# 7     True
# dtype: bool

# %%
df1.drop_duplicates() # remove duplicate row
# Out:
#       Name   Age      City Gender               Email    JoinDate
# 0     Jenu  20.0  New York      F    Jenu54@gmail.com    1/5/2021
# 1  Krishna  21.0     Surat      M  Krishna4@gmail.com  15/06/2020
# 2   Khushi   NaN     Delhi      F   Khushi1@gmail.com  20/07/2021
# 3     Metu  19.0    Mumbai      F      Metu@gmail.com  12/11/2019
# 4      NaN  22.0  Banglore      M      Shrut@gmal.com         NaN

# %%
df1.duplicated(subset=["Name","Age"]) # check particular column and return this.
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# 7     True
# dtype: bool

# %%
df1["Name"].str.lower()
# Out:
# 0       jenu
# 1    krishna
# 2     khushi
# 3       metu
# 4        NaN
# 5       jenu
# 6       metu
# 7       metu
# Name: Name, dtype: object

# %%
df1["City"].str.contains("mumbai",case=False)
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# 7     True
# Name: City, dtype: bool

# %% [markdown]
# #### Note:
# --> In the dataframe, never store python objects.
#
# -->If you want optimized memory allocation and optimized speed.

# %%
df["Email"].str.split("@")# This is storing a python list.
# Out:
# 0      [Jenu54, gmail.com]
# 1    [Krishna4, gmail.com]
# 2     [Khushi1, gmail.com]
# 3        [Metu, gmail.com]
# 4        [Shrut, gmal.com]
# 5      [Jenu54, gmail.com]
# 6        [Metu, gmail.com]
# 7        [Metu, gmail.com]
# Name: Email, dtype: object

# %%
type(df["Email"].str.split("@")[0])
# Out:
# list

# %%
df2 = df.dropna().copy()

# %%
df2
# Out:
#       Name   Age      City Gender               Email    JoinDate
# 0     Jenu  20.0  New York      F    Jenu54@gmail.com    1/5/2021
# 1  Krishna  21.0     Surat      M  Krishna4@gmail.com  15/06/2020
# 3     Metu  19.0    Mumbai      F      Metu@gmail.com  12/11/2019
# 5     Jenu  20.0  New York      F    Jenu54@gmail.com    1/5/2021
# 6     Metu  19.0    Mumbai      F      Metu@gmail.com  12/11/2019
# 7     Metu  19.0    Mumbai      F      Metu@gmail.com  12/11/2019

# %%
df2["Age"] = df2["Age"].astype(int)

# %%
df2
# Out:
#       Name  Age      City Gender               Email    JoinDate
# 0     Jenu   20  New York      F    Jenu54@gmail.com    1/5/2021
# 1  Krishna   21     Surat      M  Krishna4@gmail.com  15/06/2020
# 3     Metu   19    Mumbai      F      Metu@gmail.com  12/11/2019
# 5     Jenu   20  New York      F    Jenu54@gmail.com    1/5/2021
# 6     Metu   19    Mumbai      F      Metu@gmail.com  12/11/2019
# 7     Metu   19    Mumbai      F      Metu@gmail.com  12/11/2019

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, 0 to 7
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      6 non-null      object
#  1   Age       6 non-null      int64
#  2   City      6 non-null      object
#  3   Gender    6 non-null      object
#  4   Email     6 non-null      object
#  5   JoinDate  6 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 336.0+ bytes

# %%
df2
# Out:
#       Name  Age      City Gender               Email    JoinDate
# 0     Jenu   20  New York      F    Jenu54@gmail.com    1/5/2021
# 1  Krishna   21     Surat      M  Krishna4@gmail.com  15/06/2020
# 3     Metu   19    Mumbai      F      Metu@gmail.com  12/11/2019
# 5     Jenu   20  New York      F    Jenu54@gmail.com    1/5/2021
# 6     Metu   19    Mumbai      F      Metu@gmail.com  12/11/2019
# 7     Metu   19    Mumbai      F      Metu@gmail.com  12/11/2019

# %%
df
# Out:
#       Name   Age      City Gender               Email    JoinDate
# 0     Jenu  20.0  New York      F    Jenu54@gmail.com    1/5/2021
# 1  Krishna  21.0     Surat      M  Krishna4@gmail.com  15/06/2020
# 2   Khushi   NaN     Delhi      F   Khushi1@gmail.com  20/07/2021
# 3     Metu  19.0    Mumbai      F      Metu@gmail.com  12/11/2019
# 4      NaN  22.0  Banglore      M      Shrut@gmal.com         NaN
# 5     Jenu  20.0  New York      F    Jenu54@gmail.com    1/5/2021
# 6     Metu  19.0    Mumbai      F      Metu@gmail.com  12/11/2019
# 7     Metu  19.0    Mumbai      F      Metu@gmail.com  12/11/2019

# %%
# 1st type
# df2["Age group"]= df2["Age"].apply(lambda x : "Adult" if x >= 20 else "Minor")
# 2nd type
def isminor(x):
    return "Adult" if x >= 20 else "Minor"
df2["Age group"] = df2["Age"].apply(isminor)

# %%
df2
# Out:
#       Name  Age      City Gender               Email    JoinDate Age group
# 0     Jenu   20  New York      F    Jenu54@gmail.com    1/5/2021     Adult
# 1  Krishna   21     Surat      M  Krishna4@gmail.com  15/06/2020     Adult
# 3     Metu   19    Mumbai      F      Metu@gmail.com  12/11/2019     Minor
# 5     Jenu   20  New York      F    Jenu54@gmail.com    1/5/2021     Adult
# 6     Metu   19    Mumbai      F      Metu@gmail.com  12/11/2019     Minor
# 7     Metu   19    Mumbai      F      Metu@gmail.com  12/11/2019     Minor

# %%
gender_map = {"M":"Male" , "F":"Female" , "O":"Other"}
df2["Gender"]= df2["Gender"].map(gender_map)

# %%
df2
# Out:
#       Name  Age      City  Gender               Email    JoinDate Age group
# 0     Jenu   20  New York  Female    Jenu54@gmail.com    1/5/2021     Adult
# 1  Krishna   21     Surat    Male  Krishna4@gmail.com  15/06/2020     Adult
# 3     Metu   19    Mumbai  Female      Metu@gmail.com  12/11/2019     Minor
# 5     Jenu   20  New York  Female    Jenu54@gmail.com    1/5/2021     Adult
# 6     Metu   19    Mumbai  Female      Metu@gmail.com  12/11/2019     Minor
# 7     Metu   19    Mumbai  Female      Metu@gmail.com  12/11/2019     Minor

# %%
df2["City"] = df2["City"].replace({"Mumbai":"New Mumbai","Surat":"New surat"})

# %%
df2
# Out:
#       Name  Age        City  Gender               Email    JoinDate Age group
# 0     Jenu   20    New York  Female    Jenu54@gmail.com    1/5/2021     Adult
# 1  Krishna   21   New surat    Male  Krishna4@gmail.com  15/06/2020     Adult
# 3     Metu   19  New Mumbai  Female      Metu@gmail.com  12/11/2019     Minor
# 5     Jenu   20    New York  Female    Jenu54@gmail.com    1/5/2021     Adult
# 6     Metu   19  New Mumbai  Female      Metu@gmail.com  12/11/2019     Minor
# 7     Metu   19  New Mumbai  Female      Metu@gmail.com  12/11/2019     Minor
