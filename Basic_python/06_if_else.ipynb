# %%
a = 58

# %%
if(a>50):
    print("Grater")
else:
    print("Smaller")
# Out:
# Grater

# %%
a = 45

# %%
if(a > 50): # use if_elif_elif_else --> ladder khte hai
    print("Grater than 50")
elif(a > 40):
    print("Grater than 40") 
elif(a > 30):
    print("Grater than 30") 
else:
    print("Smaller")
# Out:
# Grater than 40

# %%
Age = 75

# %%
if(Age < 18):
    category="Minor"
elif(Age < 65):
    category="Adult"
else:
    category="Seniour citizen"
    
print("category: ",  category)
# Out:
# category:  Seniour citizen

# %% [markdown]
# ## Function

# %% [markdown]
# ### with Argument

# %%
def avg (a , b):
    return (a+b)/2
avg(4,6)
# Out:
# 5.0

# %% [markdown]
# ### default argument

# %%
def avg (a , b=10): # defualt argument b=10
    return (a+b)/2
avg(4) # b taken defult value
# Out:
# 7.0

# %%
def greet():
    print("Hello good morning")

# %%
greet()
# Out:
# Hello good morning

# %% [markdown]
# ### none python me ek object hai mins function return kuch nhi kar raha Ex:greet()
# ### python return kuch nhi karta use none khte hai

# %%
None #reserve keyword
