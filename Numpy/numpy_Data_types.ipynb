# %%
import numpy as np

# %%
arr = np.array([1,25,4,5,64])

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
arr.astype('float64')
# Out:
# array([ 1., 25.,  4.,  5., 64.])

# %% [markdown]
# #### changing data type

# %%
arr2 = np.array([1,25,4,5,64], dtype='float32')

# %%
arr2
# Out:
# array([ 1., 25.,  4.,  5., 64.], dtype=float32)

# %%
arr.nbytes
# Out:
# 40

# %%
arr2.nbytes
# Out:
# 20

# %%
arr32 = np.array([1,2,3], dtype='int32')
arr64 = np.array([1,2,3], dtype='int64')
print(arr32.nbytes)
print(arr64.nbytes)
# Out:
# 12
# 24
